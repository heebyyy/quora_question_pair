# %%
import pandas as pd
import os
import ast

# %%
if os.path.isfile('/content/drive/MyDrive/projects/quora_question_pair/nlp_features_train.csv'):
    dfnlp = pd.read_csv("/content/drive/MyDrive/projects/quora_question_pair/nlp_features_train.csv",encoding='latin-1')
else:
    print("Data not found")

if os.path.isfile('/content/drive/MyDrive/projects/quora_question_pair/df_fe_without_preprocessing_train.csv'):
    dfppro = pd.read_csv("/content/drive/MyDrive/projects/quora_question_pair/df_fe_without_preprocessing_train.csv",encoding='latin-1')
else:
    print("Data not found")
if os.path.isfile('/content/drive/MyDrive/projects/quora_question_pair/features_w2v.csv'):
    df = pd.read_csv("/content/drive/MyDrive/projects/quora_question_pair/features_w2v.csv",encoding='latin-1')
else:
    print("Data not found")

# %%
dfnlp.head(2)
# Out:
#    id  qid1  qid2                                          question1  \
# 0   0     1     2  what is the step by step guide to invest in sh...
# 1   1     3     4  what is the story of kohinoor  koh i noor  dia...
#
#                                            question2  is_duplicate   cwc_min  \
# 0  what is the step by step guide to invest in sh...             0  0.999980
# 1  what would happen if the indian government sto...             0  0.799984
#
#     cwc_max   csc_min   csc_max  ...   ctc_max  last_word_eq  first_word_eq  \
# 0  0.833319  0.999983  0.999983  ...  0.785709           0.0            1.0
# 1  0.399996  0.749981  0.599988  ...  0.466664           0.0            1.0
#
#    abs_len_diff  mean_len  token_set_ratio  token_sort_ratio  fuzz_ratio  \
# 0           2.0      13.0              100                93          93
# 1           5.0      12.5               86                63          66
#
#    fuzz_partial_ratio  longest_substr_ratio
# 0                 100              0.982759
# 1                  75              0.596154
#
# [2 rows x 21 columns]

# %%
dfppro.head(2)
# Out:
#    id  qid1  qid2                                          question1  \
# 0   0     1     2  What is the step by step guide to invest in sh...
# 1   1     3     4  What is the story of Kohinoor (Koh-i-Noor) Dia...
#
#                                            question2  is_duplicate  freq_qid1  \
# 0  What is the step by step guide to invest in sh...             0          1
# 1  What would happen if the Indian government sto...             0          4
#
#    freq_qid2  q1len  q2len  q1_n_words  q2_n_words  word_Common  word_Total  \
# 0          1     66     57          14          12         10.0        23.0
# 1          1     51     88           8          13          4.0        20.0
#
#    word_share  freq_q1+q2  freq_q1-q2
# 0    0.434783           2           0
# 1    0.200000           5           3

# %%
df.head(2)
# Out:
#    id  qid1  qid2                                          question1  \
# 0   0     1     2  What is the step by step guide to invest in sh...
# 1   1     3     4  What is the story of Kohinoor (Koh-i-Noor) Dia...
#
#                                            question2  is_duplicate  \
# 0  What is the step by step guide to invest in sh...             0
# 1  What would happen if the Indian government sto...             0
#
#                                           q1_feats_m  \
# 0  [-1.73020406e+01  6.50779065e+01 -2.62939456e+...
# 1  [ -21.27127695   42.3414979    84.17752051 -10...
#
#                                           q2_feats_m
# 0  [  -5.9516468    77.03271556 -248.92320228  -2...
# 1  [-1.11667871e+02  1.08646075e+02 -2.92446122e+...

# %%
df1 = dfnlp.drop(['qid1','qid2','question1','question2'],axis=1)
df2 = dfppro.drop(['qid1','qid2','question1','question2','is_duplicate'],axis=1)
df3 = df.drop(['qid1','qid2','question1','question2','is_duplicate'],axis=1)

df3_q1 = pd.DataFrame(df3.q1_feats_m.values.tolist(), index= df3.index)
df3_q2 = pd.DataFrame(df3.q2_feats_m.values.tolist(), index= df3.index)

# %%
# storing the final features to csv file
if not os.path.isfile('final_features.csv'):
    df3_q1['id']=df1['id']
    df3_q2['id']=df1['id']
    df1  = df1.merge(df2, on='id',how='left')
    df2  = df3_q1.merge(df3_q2, on='id',how='left')
    result  = df1.merge(df2, on='id',how='left')
    result.to_csv('/content/drive/MyDrive/projects/quora_question_pair/final_features.csv')
